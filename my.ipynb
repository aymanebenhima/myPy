# %% [markdown]
# # Introduction to Python for AI and Machine Learning
#
# This notebook covers the fundamentals of Python programming with a focus on AI and machine learning applications.

# %% [markdown]
# ## 1. Python Basics

# %%
# Variables and data types
name = "Python"
version = 3.9
is_powerful = True

print(f"Welcome to {name} {version}!")
print(f"Is Python powerful? {is_powerful}")
# Out:
# Welcome to Python 3.9!
# Is Python powerful? True

# %% [markdown]
# ## 2. Libraries for AI and ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 3. Working with NumPy

# %%
arr = np.array([1, 2, 3, 4, 5])
matrix = np.array([[1, 2, 3], [4, 5, 6]])

print("Array:", arr)
print("Matrix shape:", matrix.shape)
print("Mean:", np.mean(arr))
# Out:
# Array: [1 2 3 4 5]
# Matrix shape: (2, 3)
# Mean: 3.0

# %% [markdown]
# ## 4. Working with Pandas

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'], 'Age': [25, 30, 35], 'Score': [85, 90, 78]}
df = pd.DataFrame(data)

print(df)
print("\nBasic statistics:")
print(df.describe())
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     78
#
# Basic statistics:
#         Age      Score
# count   3.0   3.000000
# mean   30.0  84.333333
# std     5.0   6.027714
# min    25.0  78.000000
# 25%    27.5  81.500000
# 50%    30.0  85.000000
# 75%    32.5  87.500000
# max    35.0  90.000000

# %%
import sys
print(sys.executable)
print("Python version:", sys.version)
# Out:
# c:\Users\Youcode\Documents\dev-apps\myPy\.venv\Scripts\python.exe
# Python version: 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## 5. Visualization with Matplotlib

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Plot')
plt.legend()
plt.grid(True)
plt.show()
